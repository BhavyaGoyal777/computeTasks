# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavyaGoyal777/computeTasks/blob/main/Copy_of_workingWithJsonAndSqlFIles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc

# %%
df=pd.read_csv("data2.csv",skiprows=[8223])
new_df=pd.read_csv("data2.csv",skiprows=[8223])
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education.num   32560 non-null  int64
#  5   marital.status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital.gain    32560 non-null  int64
#  11  capital.loss    32560 non-null  int64
#  12  hours.per.week  32560 non-null  int64
#  13  native.country  32560 non-null  object
#  14  income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.replace('?', np.nan, inplace=True)
df.isnull().sum()
# Out:
# age                  0
# workclass         1835
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1842
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.582217  1.897834e+05      10.080682   1077.681941     87.306511
# std       13.640253  1.055476e+05       2.572760   7385.403083    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32560.000000
# mean        40.438084
# std         12.347099
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
from sklearn.preprocessing import OneHotEncoder


columns_to_encode = ['sex', 'race','income']

# Initialize the OneHotEncoder
encoder = OneHotEncoder(sparse=False, drop='first')  # drop='first' to avoid the dummy variable trap

# %%
encoded_columns = encoder.fit_transform(df[columns_to_encode])

# Create a DataFrame with the encoded columns
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(columns_to_encode))

# Drop the original columns and concatenate the encoded columns
new_df.drop(columns=columns_to_encode, inplace=True)
new_df = pd.concat([df, encoded_df], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df.drop(columns=['fnlwgt'],inplace=True)

# %%
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
sns.histplot(data=df, x='income', hue='race', multiple='stack')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Race')
plt.show()

# %%
sns.histplot(data=df, x='income', hue='sex', multiple='stack')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Sex')
plt.show()

# %%
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
sns.histplot(data=df, x='income', hue='relationship', multiple='stack')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Sex')
plt.show()

# %%
sns.histplot(data=df, x='income', hue='marital.status', multiple='stack')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Sex')
plt.show()

# %%
sns.histplot(data=df, x='income', hue='workclass')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Sex')
plt.show()

# %%
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
sns.histplot(data=df, x='income', hue='education')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by Sex')
plt.show()

# %%
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
sns.histplot(data=df, x='income', hue='education.num')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by nuimber of years in education')
plt.show()

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1835
# education            0
# education.num        0
# marital.status       0
# occupation        1842
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
one_hot_encoded_column=['race','sex','income']
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       30725 non-null  object
#  2   education       32560 non-null  object
#  3   education.num   32560 non-null  int64
#  4   marital.status  32560 non-null  object
#  5   occupation      30718 non-null  object
#  6   relationship    32560 non-null  object
#  7   race            32560 non-null  object
#  8   sex             32560 non-null  object
#  9   capital.gain    32560 non-null  int64
#  10  capital.loss    32560 non-null  int64
#  11  hours.per.week  32560 non-null  int64
#  12  native.country  31977 non-null  object
#  13  income          32560 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
df['income']=df['income'].map({'<=50K': 0, '>50K': 1})
df['sex']=df['sex'].map({'Male': 1,'Female': 0})
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 0                NaN  Not-in-family  White    0             0          4356
# 1    Exec-managerial  Not-in-family  White    0             0          4356
# 2                NaN      Unmarried  Black    0             0          4356
# 3  Machine-op-inspct      Unmarried  White    0             0          3900
# 4     Prof-specialty      Own-child  White    0             0          3900
#
#    hours.per.week native.country  income
# 0              40  United-States       0
# 1              18  United-States       0
# 2              40  United-States       0
# 3              40  United-States       0
# 4              40  United-States       0

# %%
sns.histplot(data=df, x='income', hue='native.country')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income by nuimber of years in education')
plt.show()

# %%
print(df['native.country'].value_counts())
df["native.country"] = df["native.country"].fillna("United-States")
df.head()
# Out:
# native.country
# United-States                 29169
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# Greece                           29
# France                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Trinadad&Tobago                  19
# Cambodia                         19
# Thailand                         18
# Laos                             18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Hungary                          13
# Honduras                         13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 0                NaN  Not-in-family  White    0             0          4356
# 1    Exec-managerial  Not-in-family  White    0             0          4356
# 2                NaN      Unmarried  Black    0             0          4356
# 3  Machine-op-inspct      Unmarried  White    0             0          3900
# 4     Prof-specialty      Own-child  White    0             0          3900
#
#    hours.per.week native.country  income
# 0              40  United-States       0
# 1              18  United-States       0
# 2              40  United-States       0
# 3              40  United-States       0
# 4              40  United-States       0

# %%
numeric_features = ['age','education.num','capital.gain','capital.loss','hours.per.week','income']
df[numeric_features].corr()
# Out:
#                      age  education.num  capital.gain  capital.loss  \
# age             1.000000       0.036527      0.077671      0.057767
# education.num   0.036527       1.000000      0.122630      0.079923
# capital.gain    0.077671       0.122630      1.000000     -0.031616
# capital.loss    0.057767       0.079923     -0.031616      1.000000
# hours.per.week  0.068691       0.148127      0.078405      0.054248
# income          0.234021       0.335155      0.223327      0.150523
#
#                 hours.per.week    income
# age                   0.068691  0.234021
# education.num         0.148127  0.335155
# capital.gain          0.078405  0.223327
# capital.loss          0.054248  0.150523
# hours.per.week        1.000000  0.229671
# income                0.229671  1.000000

# %%
print(df['workclass'].value_counts())
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
print(df['occupation'].value_counts())
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3533

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#    age workclass     education  education.num marital.status  \
# 0   90       NaN       HS-grad              9        Widowed
# 1   82   Private       HS-grad              9        Widowed
# 2   66       NaN  Some-college             10        Widowed
# 3   54   Private       7th-8th              4       Divorced
# 4   41   Private  Some-college             10      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 0                NaN  Not-in-family  White    0             0          4356
# 1    Exec-managerial  Not-in-family  White    0             0          4356
# 2                NaN      Unmarried  Black    0             0          4356
# 3  Machine-op-inspct      Unmarried  White    0             0          3900
# 4     Prof-specialty      Own-child  White    0             0          3900
#
#    hours.per.week native.country  income
# 0              40  United-States       0
# 1              18  United-States       0
# 2              40  United-States       0
# 3              40  United-States       0
# 4              40  United-States       0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
another_df=df

# %%
another_df.isnull().sum()
# Out:
# age                  0
# workclass         1629
# education            0
# education.num        0
# marital.status       0
# occupation        1636
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country       0
# income               0
# dtype: int64

# %%
another_df=another_df.dropna()
another_df.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
another_df
# Out:
#        age workclass     education  education.num      marital.status  \
# 1       82   Private       HS-grad              9             Widowed
# 3       54   Private       7th-8th              4            Divorced
# 4       41   Private  Some-college             10           Separated
# 5       34   Private       HS-grad              9            Divorced
# 6       38   Private          10th              6           Separated
# ...    ...       ...           ...            ...                 ...
# 32553   32   Private       Masters             14       Never-married
# 32554   53   Private       Masters             14  Married-civ-spouse
# 32555   22   Private  Some-college             10       Never-married
# 32556   27   Private    Assoc-acdm             12  Married-civ-spouse
# 32558   58   Private       HS-grad              9             Widowed
#
#               occupation   relationship                race  sex  \
# 1        Exec-managerial  Not-in-family               White    0
# 3      Machine-op-inspct      Unmarried               White    0
# 4         Prof-specialty      Own-child               White    0
# 5          Other-service      Unmarried               White    0
# 6           Adm-clerical      Unmarried               White    1
# ...                  ...            ...                 ...  ...
# 32553       Tech-support  Not-in-family  Asian-Pac-Islander    1
# 32554    Exec-managerial        Husband               White    1
# 32555    Protective-serv  Not-in-family               White    1
# 32556       Tech-support           Wife               White    0
# 32558       Adm-clerical      Unmarried               White    0
#
#        capital.gain  capital.loss  hours.per.week native.country  income
# 1                 0          4356              18  United-States       0
# 3                 0          3900              40  United-States       0
# 4                 0          3900              40  United-States       0
# 5                 0          3770              45  United-States       0
# 6                 0          3770              40  United-States       0
# ...             ...           ...             ...            ...     ...
# 32553             0             0              11         Taiwan       0
# 32554             0             0              40  United-States       1
# 32555             0             0              40  United-States       0
# 32556             0             0              38  United-States       0
# 32558             0             0              40  United-States       0
#
# [27391 rows x 14 columns]

# %%
g = sns.catplot(x="relationship",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-44-b1122c426664>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="relationship",y="income",data=another_df,kind="bar",

# %%
g = sns.catplot(x="marital.status",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-45-f0cf20b37bc8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="marital.status",y="income",data=another_df,kind="bar",

# %%
another_df["marital.status"] =another_df["marital.status"].replace(['Never-married','Divorced','Separated','Widowed'], 'Single')
another_df["marital.status"] = another_df["marital.status"].replace(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'], 'Married')
another_df["marital.status"] = another_df["marital.status"].map({"Married":1, "Single":0})
another_df["marital.status"] = another_df["marital.status"].astype(int)
# Out:
# <ipython-input-46-463ac0db4d34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df["marital.status"] =another_df["marital.status"].replace(['Never-married','Divorced','Separated','Widowed'], 'Single')
# <ipython-input-46-463ac0db4d34>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df["marital.status"] = another_df["marital.status"].replace(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'], 'Married')
# <ipython-input-46-463ac0db4d34>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df["marital.status"] = another_df["marital.status"].map({"Married":1, "Single":0})
# <ipython-input-46-463ac0db4d34>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df["marital.status"] = another_df["marital.status"].astype(int)

# %%
another_df
# Out:
#        age workclass     education  education.num  marital.status  \
# 1       82   Private       HS-grad              9               0
# 3       54   Private       7th-8th              4               0
# 4       41   Private  Some-college             10               0
# 5       34   Private       HS-grad              9               0
# 6       38   Private          10th              6               0
# ...    ...       ...           ...            ...             ...
# 32553   32   Private       Masters             14               0
# 32554   53   Private       Masters             14               1
# 32555   22   Private  Some-college             10               0
# 32556   27   Private    Assoc-acdm             12               1
# 32558   58   Private       HS-grad              9               0
#
#               occupation   relationship                race  sex  \
# 1        Exec-managerial  Not-in-family               White    0
# 3      Machine-op-inspct      Unmarried               White    0
# 4         Prof-specialty      Own-child               White    0
# 5          Other-service      Unmarried               White    0
# 6           Adm-clerical      Unmarried               White    1
# ...                  ...            ...                 ...  ...
# 32553       Tech-support  Not-in-family  Asian-Pac-Islander    1
# 32554    Exec-managerial        Husband               White    1
# 32555    Protective-serv  Not-in-family               White    1
# 32556       Tech-support           Wife               White    0
# 32558       Adm-clerical      Unmarried               White    0
#
#        capital.gain  capital.loss  hours.per.week native.country  income
# 1                 0          4356              18  United-States       0
# 3                 0          3900              40  United-States       0
# 4                 0          3900              40  United-States       0
# 5                 0          3770              45  United-States       0
# 6                 0          3770              40  United-States       0
# ...             ...           ...             ...            ...     ...
# 32553             0             0              11         Taiwan       0
# 32554             0             0              40  United-States       1
# 32555             0             0              40  United-States       0
# 32556             0             0              38  United-States       0
# 32558             0             0              40  United-States       0
#
# [27391 rows x 14 columns]

# %%
g = sns.catplot(x="education",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-48-a441e7c214e9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="education",y="income",data=another_df,kind="bar",

# %%
g = sns.catplot(x="education.num",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-49-a839f8254612>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="education.num",y="income",data=another_df,kind="bar",

# %%
import pandas as pd



# Define the mapping
label_mapping = {
    1: 7,
    2: 1, 3: 1,
    4: 0, 5: 0, 6: 0, 7: 0, 8: 0,
    9: 2, 10: 2,
    11: 3, 12: 3,
    13: 4,
    14: 5,
    15: 6, 16: 6
}

# Apply the mapping to the column
df['education.num_mapped'] = df['education.num'].map(label_mapping)
df['education.num_mapped'].value_counts()

another_df['education.num']=df['education.num_mapped']
# Out:
# <ipython-input-50-0b29372daaf5>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df['education.num']=df['education.num_mapped']

# %%
g = sns.catplot(x="education.num",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-51-a839f8254612>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="education.num",y="income",data=another_df,kind="bar",

# %%
g = sns.catplot(x="education",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-52-a441e7c214e9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="education",y="income",data=another_df,kind="bar",

# %%
another_df['education'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd



# Define the mapping
label_mapping = {
    '10th': 0,'11th':0,'7th-8th':0,'12th':0,
    '1st-4th':1,'5th-6th':1,'9th':1,'Preschool':6,
    'Assoc-acdm':2,'Assoc-voc':2,
    'HS-grad':2,'Some-college':2,
    'Bachelors':3,'Masters':4,
    'Doctorate':5,'Prof-school':5






}

# Apply the mapping to the column
df['education.num_mapped'] = df['education'].map(label_mapping)
df['education.num_mapped'].value_counts()

another_df['education']=df['education.num_mapped']
# Out:
# <ipython-input-54-1bc0e48830bc>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df['education']=df['education.num_mapped']

# %%
print(another_df['education'].value_counts().sum())
another_df['education'].isnull().sum()
# Out:
# 27391
# 0

# %%
another_df['capital.gain'].value_counts()
# Out:
# capital.gain
# 0        24816
# 15024      337
# 7688       274
# 7298       242
# 99999      154
#          ...
# 6097         1
# 1639         1
# 7978         1
# 2387         1
# 22040        1
# Name: count, Length: 118, dtype: int64

# %%
another_df['capital.loss'].value_counts()
# Out:
# capital.loss
# 0       25938
# 1902      199
# 1977      165
# 1887      155
# 1848       49
#         ...
# 1844        1
# 2201        1
# 1944        1
# 1411        1
# 4356        1
# Name: count, Length: 90, dtype: int64

# %%
import pandas as pd



# Define the mapping
label_mapping = {
    'Husband':1,'Wife':1
    ,'Not-in-family':0,'Own-child':0,
    'Unmarried':0,'Other-relative':0





}

# Apply the mapping to the column
df['education.num_mapped'] = df['relationship'].map(label_mapping)
df['education.num_mapped'].value_counts()

another_df['relationship']=df['education.num_mapped']
# Out:
# <ipython-input-58-655d23759c81>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df['relationship']=df['education.num_mapped']

# %%
another_df['relationship']
another_df['relationship'].isnull().sum()
# Out:
# 0

# %%
another_df.head()
# Out:
#    age workclass  education  education.num  marital.status         occupation  \
# 1   82   Private          2              2               0    Exec-managerial
# 3   54   Private          0              0               0  Machine-op-inspct
# 4   41   Private          2              2               0     Prof-specialty
# 5   34   Private          2              2               0      Other-service
# 6   38   Private          0              0               0       Adm-clerical
#
#    relationship   race  sex  capital.gain  capital.loss  hours.per.week  \
# 1             0  White    0             0          4356              18
# 3             0  White    0             0          3900              40
# 4             0  White    0             0          3900              40
# 5             0  White    0             0          3770              45
# 6             0  White    1             0          3770              40
#
#   native.country  income
# 1  United-States       0
# 3  United-States       0
# 4  United-States       0
# 5  United-States       0
# 6  United-States       0

# %%
# y_column=another_df['income']
# another_df=another_df.drop(columns=['income'],)
# another_df.head()

# %%
g = sns.catplot(x="workclass",y="income",data=another_df,kind="bar",
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
g.set_xticklabels(rotation=90)
g
# Out:
# <ipython-input-62-8a6f796b5b0a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="workclass",y="income",data=another_df,kind="bar",

# %%
import pandas as pd



# Define the mapping
label_mapping = {
    'Self-emp-not-inc':1
    ,'Private':0,'Local-gov':0,'State-gov':0,'Federal-gov':0,'Self-emp-inc':0,'Without-pay':0,'Never-worked':0





}

# Apply the mapping to the column
df['education.num_mapped'] = df['workclass'].map(label_mapping)
df['education.num_mapped'].value_counts()

another_df['workclass']=df['education.num_mapped']
# Out:
# <ipython-input-63-6672444e30d9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   another_df['workclass']=df['education.num_mapped']

# %%
another_df.head()
# Out:
#    age  workclass  education  education.num  marital.status  \
# 1   82        0.0          2              2               0
# 3   54        0.0          0              0               0
# 4   41        0.0          2              2               0
# 5   34        0.0          2              2               0
# 6   38        0.0          0              0               0
#
#           occupation  relationship   race  sex  capital.gain  capital.loss  \
# 1    Exec-managerial             0  White    0             0          4356
# 3  Machine-op-inspct             0  White    0             0          3900
# 4     Prof-specialty             0  White    0             0          3900
# 5      Other-service             0  White    0             0          3770
# 6       Adm-clerical             0  White    1             0          3770
#
#    hours.per.week native.country  income
# 1              18  United-States       0
# 3              40  United-States       0
# 4              40  United-States       0
# 5              45  United-States       0
# 6              40  United-States       0

# %%
Y=another_df['income']
X=another_df.iloc[:,:12]
X.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# dtype: int64

# %%
X.head()
another_df=another_df.drop(columns=['native.country','race','occupation'])
Y=another_df['income']
X=another_df.iloc[:,:12]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
# Initialize the Random Forest regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)


rf_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf_regressor.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 100.00%

# %%
X_test
# Out:
#        age  workclass  education  education.num  marital.status  relationship  \
# 26870   25        0.0          0              0               0             0
# 21479   31        0.0          3              4               0             0
# 27689   49        0.0          0              0               1             1
# 2494    58        0.0          3              4               1             1
# 26802   42        0.0          2              2               1             1
# ...    ...        ...        ...            ...             ...           ...
# 29197   34        0.0          3              4               0             0
# 11845   26        0.0          2              2               0             0
# 29631   31        0.0          2              2               0             0
# 30009   31        0.0          3              4               0             0
# 29870   39        0.0          0              0               1             1
#
#        sex  capital.gain  capital.loss  hours.per.week  income
# 26870    1             0             0              40       0
# 21479    1             0             0              40       0
# 27689    1             0             0              40       1
# 2494     1          7688             0              50       1
# 26802    0             0             0              40       1
# ...    ...           ...           ...             ...     ...
# 29197    0             0             0              40       0
# 11845    1             0             0              40       0
# 29631    0             0             0              99       1
# 30009    1             0             0              40       0
# 29870    1             0             0              35       0
#
# [5479 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
cv_scores = cross_val_score(rf_regressor, X, Y, cv=5)
cv_scores
# Out:
# array([1., 1., 1., 1., 1.])

# %%
print(f'Cross-validation scores: {cv_scores}')
print(f'Average cross-validation score: {cv_scores.mean()}')
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Average cross-validation score: 1.0
