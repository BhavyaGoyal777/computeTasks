# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavyaGoyal777/computeTasks/blob/main/mlTask_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("data2.csv",skiprows=[8223])
new_df=pd.read_csv("data2.csv",skiprows=[8223])
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education.num   32560 non-null  int64
#  5   marital.status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital.gain    32560 non-null  int64
#  11  capital.loss    32560 non-null  int64
#  12  hours.per.week  32560 non-null  int64
#  13  native.country  32560 non-null  object
#  14  income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.replace('?', np.nan, inplace=True)
df.isnull().sum()
# Out:
# age                  0
# workclass         1835
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1842
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.582217  1.897834e+05      10.080682   1077.681941     87.306511
# std       13.640253  1.055476e+05       2.572760   7385.403083    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32560.000000
# mean        40.438084
# std         12.347099
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1835
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1842
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['income']=df['income'].map({'<=50K': 0, '>50K': 1})
# Out:
# <ipython-input-11-1b25a10f63e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income']=df['income'].map({'<=50K': 0, '>50K': 1})

# %%
df["workclass"] = df["workclass"].fillna("Private")
df["native.country"] = df["native.country"].fillna("United-States")
# Out:
# <ipython-input-12-c69d22bad1fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["workclass"] = df["workclass"].fillna("Private")
# <ipython-input-12-c69d22bad1fc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["native.country"] = df["native.country"].fillna("United-States")

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90   Private   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66   Private  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country  income
# 0          4356              40  United-States       0
# 1          4356              18  United-States       0
# 2          4356              40  United-States       0
# 3          3900              40  United-States       0
# 4          3900              40  United-States       0

# %%
numeric_features = ['age','education.num','capital.gain','capital.loss','hours.per.week','income']

# %%
df= df.dropna(subset=['occupation'])

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country  income
# 1          4356              18  United-States       0
# 3          3900              40  United-States       0
# 4          3900              40  United-States       0
# 5          3770              45  United-States       0
# 6          3770              40  United-States       0

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
label_encoder = LabelEncoder()
categorical_columns = ['income', 'workclass', 'education', 'relationship', 'occupation',  'race', 'sex', 'native.country']
df[categorical_columns] = df[categorical_columns].apply(label_encoder.fit_transform)
df["marital.status"] =df["marital.status"].replace(['Never-married','Divorced','Separated','Widowed'], 'Single')
df["marital.status"] = df["marital.status"].replace(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'], 'Married')
df["marital.status"] = df["marital.status"].map({"Married":1, "Single":0})
df["marital.status"] = df["marital.status"].astype(int)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 1   82          2  132870         11              9               0
# 3   54          2  140359          5              4               0
# 4   41          2  264663         15             10               0
# 5   34          2  216864         11              9               0
# 6   38          2  150601          0              6               0
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 1           3             1     4    0             0          4356
# 3           6             4     4    0             0          3900
# 4           9             3     4    0             0          3900
# 5           7             4     4    0             0          3770
# 6           0             4     4    1             0          3770
#
#    hours.per.week  native.country  income
# 1              18              38       0
# 3              40              38       0
# 4              40              38       0
# 5              45              38       0
# 6              40              38       0

# %%
import statsmodels.api as sm
new_x=df[numeric_features]
new_y=df['income']
new_x=sm.add_constant(new_x)
ssm=sm.OLS(new_y,new_x)
fit=ssm.fit()
print(fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.075e+30
# Date:                Tue, 06 Aug 2024   Prob (F-statistic):               0.00
# Time:                        08:02:44   Log-Likelihood:             9.3280e+05
# No. Observations:               30694   AIC:                        -1.866e+06
# Df Residuals:                   30687   BIC:                        -1.866e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.032e-15   5.18e-16      7.777      0.000    3.02e-15    5.05e-15
# age            -1.163e-16    6.9e-18    -16.866      0.000    -1.3e-16   -1.03e-16
# education.num   3.249e-16   3.65e-17      8.908      0.000    2.53e-16    3.96e-16
# capital.gain   -1.051e-18    1.2e-20    -87.480      0.000   -1.07e-18   -1.03e-18
# capital.loss   -3.169e-17   2.19e-19   -144.785      0.000   -3.21e-17   -3.13e-17
# hours.per.week  -5.02e-17   7.54e-18     -6.660      0.000    -6.5e-17   -3.54e-17
# income             1.0000    2.3e-16   4.35e+15      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                    26205.769   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           551142.838
# Skew:                           4.258   Prob(JB):                         0.00
# Kurtosis:                      21.932   Cond. No.                     4.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
q=sm.qqplot(fit.resid,line='r')
plt.show()
np.mean(fit.resid)
# Out:
# 3.075768569900964e-15

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['income']), df['income'], test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
print('**** ACCURACY_SCORE **** \n\n', accuracy_score(y_test, y_pred), '\n')
print('**** CLASSIFICATION_REPORT **** \n\n', classification_report(y_test, y_pred), '\n')
# Out:
# **** ACCURACY_SCORE ****
#
#  0.8564912852256068
#
# **** CLASSIFICATION_REPORT ****
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4699
#            1       0.73      0.62      0.67      1440
#
#     accuracy                           0.86      6139
#    macro avg       0.81      0.77      0.79      6139
# weighted avg       0.85      0.86      0.85      6139

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report


xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Set up the hyperparameter grid
param_grid = {
    'colsample_bytree': [0.6],
    'learning_rate': [0.1],
    'max_depth': [7],
    'n_estimators': [100],
    'subsample': [1.0]
}

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid,
                           scoring='accuracy', cv=3, verbose=1, n_jobs=-1)

# Fit the model
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Hyperparameters:\n", best_params)

# Predict using the best estimator
y_pred = grid_search.best_estimator_.predict(x_test)

# Print evaluation metrics
print('**** ACCURACY_SCORE **** \n\n', accuracy_score(y_test, y_pred), '\n')
print('**** CLASSIFICATION_REPORT **** \n\n', classification_report(y_test, y_pred), '\n')
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:02:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Hyperparameters:
#  {'colsample_bytree': 0.6, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0}
# **** ACCURACY_SCORE ****
#
#  0.8794591953086822
#
# **** CLASSIFICATION_REPORT ****
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      4699
#            1       0.79      0.66      0.72      1440
#
#     accuracy                           0.88      6139
#    macro avg       0.85      0.80      0.82      6139
# weighted avg       0.88      0.88      0.88      6139

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

xgb = XGBClassifier()
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
print('**** ACCURACY_SCORE **** \n\n', accuracy_score(y_test, y_pred), '\n')
print('**** CLASSIFICATION_REPORT **** \n\n', classification_report(y_test, y_pred), '\n')
# Out:
# **** ACCURACY_SCORE ****
#
#  0.8705000814464896
#
# **** CLASSIFICATION_REPORT ****
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      4699
#            1       0.76      0.66      0.70      1440
#
#     accuracy                           0.87      6139
#    macro avg       0.83      0.80      0.81      6139
# weighted avg       0.87      0.87      0.87      6139

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2

# %%
# Build the model
model = Sequential([

    Dense(25, activation='relu', kernel_regularizer=l2(0.01)),
    Dense(10, activation='relu', kernel_regularizer=l2(0.01)),

    Dense(1, activation='sigmoid')  # Use 'softmax' for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=50, batch_size=8, validation_split=0.2)
# Out:
# Epoch 1/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.7951 - loss: 0.5795 - val_accuracy: 0.8381 - val_loss: 0.3855
# Epoch 2/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8366 - loss: 0.3816 - val_accuracy: 0.8357 - val_loss: 0.3693
# Epoch 3/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8410 - loss: 0.3682 - val_accuracy: 0.8383 - val_loss: 0.3633
# Epoch 4/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8340 - loss: 0.3643 - val_accuracy: 0.8383 - val_loss: 0.3611
# Epoch 5/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.8413 - loss: 0.3595 - val_accuracy: 0.8334 - val_loss: 0.3612
# Epoch 6/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8349 - loss: 0.3638 - val_accuracy: 0.8412 - val_loss: 0.3596
# Epoch 7/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8348 - loss: 0.3627 - val_accuracy: 0.8391 - val_loss: 0.3591
# Epoch 8/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8440 - loss: 0.3509 - val_accuracy: 0.8420 - val_loss: 0.3577
# Epoch 9/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8427 - loss: 0.3535 - val_accuracy: 0.8379 - val_loss: 0.3560
# Epoch 10/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8356 - loss: 0.3631 - val_accuracy: 0.8397 - val_loss: 0.3533
# Epoch 11/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8418 - loss: 0.3543 - val_accuracy: 0.8402 - val_loss: 0.3555
# Epoch 12/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8382 - loss: 0.3540 - val_accuracy: 0.8381 - val_loss: 0.3556
# Epoch 13/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8412 - loss: 0.3522 - val_accuracy: 0.8367 - val_loss: 0.3538
# Epoch 14/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8392 - loss: 0.3573 - val_accuracy: 0.8410 - val_loss: 0.3518
# Epoch 15/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8398 - loss: 0.3533 - val_accuracy: 0.8400 - val_loss: 0.3516
# Epoch 16/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8380 - loss: 0.3539 - val_accuracy: 0.8408 - val_loss: 0.3505
# Epoch 17/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8401 - loss: 0.3502 - val_accuracy: 0.8397 - val_loss: 0.3563
# Epoch 18/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8395 - loss: 0.3529 - val_accuracy: 0.8400 - val_loss: 0.3519
# Epoch 19/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8413 - loss: 0.3496 - val_accuracy: 0.8400 - val_loss: 0.3513
# Epoch 20/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8346 - loss: 0.3588 - val_accuracy: 0.8363 - val_loss: 0.3567
# Epoch 21/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8355 - loss: 0.3607 - val_accuracy: 0.8400 - val_loss: 0.3509
# Epoch 22/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8360 - loss: 0.3511 - val_accuracy: 0.8395 - val_loss: 0.3526
# Epoch 23/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8348 - loss: 0.3568 - val_accuracy: 0.8434 - val_loss: 0.3491
# Epoch 24/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8378 - loss: 0.3534 - val_accuracy: 0.8424 - val_loss: 0.3502
# Epoch 25/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8322 - loss: 0.3623 - val_accuracy: 0.8418 - val_loss: 0.3505
# Epoch 26/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8412 - loss: 0.3512 - val_accuracy: 0.8430 - val_loss: 0.3489
# Epoch 27/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8408 - loss: 0.3533 - val_accuracy: 0.8391 - val_loss: 0.3501
# Epoch 28/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8411 - loss: 0.3488 - val_accuracy: 0.8308 - val_loss: 0.3557
# Epoch 29/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8401 - loss: 0.3499 - val_accuracy: 0.8379 - val_loss: 0.3545
# Epoch 30/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8399 - loss: 0.3523 - val_accuracy: 0.8406 - val_loss: 0.3484
# Epoch 31/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8401 - loss: 0.3489 - val_accuracy: 0.8440 - val_loss: 0.3486
# Epoch 32/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.8341 - loss: 0.3554 - val_accuracy: 0.8406 - val_loss: 0.3478
# Epoch 33/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8413 - loss: 0.3470 - val_accuracy: 0.8434 - val_loss: 0.3524
# Epoch 34/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8430 - loss: 0.3475 - val_accuracy: 0.8424 - val_loss: 0.3481
# Epoch 35/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8371 - loss: 0.3494 - val_accuracy: 0.8279 - val_loss: 0.3593
# Epoch 36/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8400 - loss: 0.3532 - val_accuracy: 0.8393 - val_loss: 0.3495
# Epoch 37/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8407 - loss: 0.3476 - val_accuracy: 0.8426 - val_loss: 0.3467
# Epoch 38/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8397 - loss: 0.3521 - val_accuracy: 0.8404 - val_loss: 0.3465
# Epoch 39/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8414 - loss: 0.3481 - val_accuracy: 0.8397 - val_loss: 0.3516
# Epoch 40/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8403 - loss: 0.3512 - val_accuracy: 0.8412 - val_loss: 0.3501
# Epoch 41/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8390 - loss: 0.3507 - val_accuracy: 0.8418 - val_loss: 0.3461
# Epoch 42/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8395 - loss: 0.3487 - val_accuracy: 0.8412 - val_loss: 0.3479
# Epoch 43/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8371 - loss: 0.3518 - val_accuracy: 0.8391 - val_loss: 0.3540
# Epoch 44/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8393 - loss: 0.3534 - val_accuracy: 0.8385 - val_loss: 0.3502
# Epoch 45/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8411 - loss: 0.3458 - val_accuracy: 0.8412 - val_loss: 0.3470
# Epoch 46/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8387 - loss: 0.3480 - val_accuracy: 0.8402 - val_loss: 0.3489
# Epoch 47/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8418 - loss: 0.3460 - val_accuracy: 0.8424 - val_loss: 0.3498
# Epoch 48/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8418 - loss: 0.3450 - val_accuracy: 0.8420 - val_loss: 0.3473
# Epoch 49/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8361 - loss: 0.3524 - val_accuracy: 0.8389 - val_loss: 0.3468
# Epoch 50/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8385 - loss: 0.3483 - val_accuracy: 0.8393 - val_loss: 0.3460

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')
print('**** CONFUSION MATRIX ****')
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8468 - loss: 0.3418
# Accuracy: 84.80%
# **** CONFUSION MATRIX ****
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)

# Evaluate the model
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 84.20%
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      4699
#            1       0.71      0.55      0.62      1440
#
#     accuracy                           0.84      6139
#    macro avg       0.79      0.74      0.76      6139
# weighted avg       0.83      0.84      0.83      6139

# %%
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8132 - loss: 0.5085 - val_accuracy: 0.8206 - val_loss: 0.3914
# Epoch 2/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8279 - loss: 0.3862 - val_accuracy: 0.8298 - val_loss: 0.3831
# Epoch 3/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8279 - loss: 0.3915 - val_accuracy: 0.8173 - val_loss: 0.3885
# Epoch 4/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8280 - loss: 0.3927 - val_accuracy: 0.8186 - val_loss: 0.3883
# Epoch 5/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8283 - loss: 0.3865 - val_accuracy: 0.8257 - val_loss: 0.3871
# Epoch 6/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8253 - loss: 0.3928 - val_accuracy: 0.8336 - val_loss: 0.3840
# Epoch 7/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8222 - loss: 0.3969 - val_accuracy: 0.8324 - val_loss: 0.3774
# Epoch 8/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8249 - loss: 0.3938 - val_accuracy: 0.8342 - val_loss: 0.3755
# Epoch 9/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8302 - loss: 0.3906 - val_accuracy: 0.8261 - val_loss: 0.3923
# Epoch 10/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8251 - loss: 0.3905 - val_accuracy: 0.8257 - val_loss: 0.3902
# Epoch 11/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8296 - loss: 0.3901 - val_accuracy: 0.8269 - val_loss: 0.3864
# Epoch 12/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8290 - loss: 0.3911 - val_accuracy: 0.8068 - val_loss: 0.4014
# Epoch 13/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8246 - loss: 0.3930 - val_accuracy: 0.8314 - val_loss: 0.3905
# Epoch 14/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8289 - loss: 0.3938 - val_accuracy: 0.8302 - val_loss: 0.3852
# Epoch 15/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8283 - loss: 0.3874 - val_accuracy: 0.8239 - val_loss: 0.4044
# Epoch 16/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8246 - loss: 0.3913 - val_accuracy: 0.8239 - val_loss: 0.3808
# Epoch 17/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8316 - loss: 0.3885 - val_accuracy: 0.8251 - val_loss: 0.3918
# Epoch 18/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8232 - loss: 0.3938 - val_accuracy: 0.8288 - val_loss: 0.3839
# Epoch 19/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8297 - loss: 0.3874 - val_accuracy: 0.8171 - val_loss: 0.4082
# Epoch 20/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8178 - loss: 0.3983 - val_accuracy: 0.8298 - val_loss: 0.3799
# Epoch 21/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8311 - loss: 0.3871 - val_accuracy: 0.8306 - val_loss: 0.3831
# Epoch 22/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8255 - loss: 0.3901 - val_accuracy: 0.8294 - val_loss: 0.3798
# Epoch 23/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8252 - loss: 0.3950 - val_accuracy: 0.8320 - val_loss: 0.3829
# Epoch 24/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8208 - loss: 0.3959 - val_accuracy: 0.8267 - val_loss: 0.3861
# Epoch 25/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8275 - loss: 0.3941 - val_accuracy: 0.8271 - val_loss: 0.3889
# Epoch 26/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8195 - loss: 0.3961 - val_accuracy: 0.8218 - val_loss: 0.3897
# Epoch 27/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8314 - loss: 0.3849 - val_accuracy: 0.8318 - val_loss: 0.3833
# Epoch 28/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8286 - loss: 0.3866 - val_accuracy: 0.8131 - val_loss: 0.4089
# Epoch 29/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8275 - loss: 0.3877 - val_accuracy: 0.8173 - val_loss: 0.4054
# Epoch 30/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8308 - loss: 0.3844 - val_accuracy: 0.8257 - val_loss: 0.3913
# Epoch 31/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8215 - loss: 0.3959 - val_accuracy: 0.8298 - val_loss: 0.3842
# Epoch 32/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8314 - loss: 0.3841 - val_accuracy: 0.8224 - val_loss: 0.3983
# Epoch 33/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8260 - loss: 0.3902 - val_accuracy: 0.8290 - val_loss: 0.4066
# Epoch 34/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8221 - loss: 0.3995 - val_accuracy: 0.8296 - val_loss: 0.3819
# Epoch 35/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8224 - loss: 0.4003 - val_accuracy: 0.8314 - val_loss: 0.3871
# Epoch 36/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8286 - loss: 0.3913 - val_accuracy: 0.8198 - val_loss: 0.3960
# Epoch 37/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8294 - loss: 0.3899 - val_accuracy: 0.8206 - val_loss: 0.3920
# Epoch 38/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8313 - loss: 0.3903 - val_accuracy: 0.8092 - val_loss: 0.4019
# Epoch 39/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8264 - loss: 0.3885 - val_accuracy: 0.8241 - val_loss: 0.3891
# Epoch 40/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8280 - loss: 0.3932 - val_accuracy: 0.8094 - val_loss: 0.4113
# Epoch 41/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8305 - loss: 0.3871 - val_accuracy: 0.8200 - val_loss: 0.3881
# Epoch 42/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8284 - loss: 0.3944 - val_accuracy: 0.8023 - val_loss: 0.4263
# Epoch 43/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8302 - loss: 0.3914 - val_accuracy: 0.8218 - val_loss: 0.4078
# Epoch 44/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8280 - loss: 0.3892 - val_accuracy: 0.8235 - val_loss: 0.3854
# Epoch 45/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8237 - loss: 0.3938 - val_accuracy: 0.8328 - val_loss: 0.3806
# Epoch 46/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8269 - loss: 0.3933 - val_accuracy: 0.8098 - val_loss: 0.4057
# Epoch 47/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8267 - loss: 0.3923 - val_accuracy: 0.7882 - val_loss: 0.4200
# Epoch 48/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8249 - loss: 0.3926 - val_accuracy: 0.8285 - val_loss: 0.3859
# Epoch 49/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8238 - loss: 0.3939 - val_accuracy: 0.8328 - val_loss: 0.3818
# Epoch 50/50
# 2456/2456 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8217 - loss: 0.3992 - val_accuracy: 0.8039 - val_loss: 0.4129
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8121 - loss: 0.4052
# Validation loss: 0.4129384756088257, Validation accuracy: 0.8039095997810364
